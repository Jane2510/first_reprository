# %% [markdown]
# <a href="https://colab.research.google.com/github/Jane2510/first_reprository/blob/main/task5_10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random

def generate_password(stdin):
    if stdin <12:
        stdin= 12
    lowercase = "abcdefghijklmnopqrstuvwxyz"
    uppercase = "ABCDEFGHIJKLMNOPQRSTUVWXYZ"
    digits = "0123456789"
    special = "~!@#$%^&*()_+."
    password = [
        random.choice(lowercase),
        random.choice(uppercase),
        random.choice(digits),
        random.choice(special)
    ]
    all_chars = lowercase + uppercase + digits + special
    for i in range(stdin - 4):
        password.append(random.choice(all_chars))
    random.shuffle(password)
    return ''.join(password)
